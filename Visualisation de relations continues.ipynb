# %% [raw]
# 1) Importez les librairies qu’il vous faut

# %%
import numpy as np
import pandas as pd
import matplotlib as mp 
import seaborn as sns

# %%
df = pd.read_csv('/Users/camilleblx/Desktop/Development-BigData/yourenv/bin/sales_predictions.csv')
print('data loaded')
# Out:
# data loaded

# %%
df
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 2935844           1.0
# 2935845           1.0
# 2935846           1.0
# 2935847           1.0
# 2935848           1.0
#
# [2935849 rows x 6 columns]

# %% [raw]
# 2) En utilisant relplot(), construisez un graphique qui va vous permettre de voir l’évolution
# des prix par rapport au temps. Que pouvez vous voir ?

# %%
sns.relplot(x='date', y='item_price', data=df)

# %% [raw]
# 3) Corrigeons le problème de visualisation, en utilisant la fonction .sample() de Pandas,
# prenez un échantillons de 50 éléments dans votre dataset

# %%
sns.relplot(x='date', y='item_price', data=df.sample(n=50))

# %% [raw]
# 4) Retentez de faire votre visualisation, créez une figure de taille (20,6). Que voyez vous ?

# %%
sns.relplot(x='date', y='item_price', data=df.sample(n=50), height=10)

# %% [raw]
# 5) En utilisant la fonction pd.to_datetime(), convertissez votre colonne date en datetime

# %%
df.date = pd.to_datetime(df.date).sample(n=50)

# %% [raw]
# 6) Retentez une dernière fois votre visualisation.

# %%
sns.relplot(x='date', y='item_price', data=df, height=10)
# Out:
# /Users/camilleblx/Desktop/Development-BigData/yourenv/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
