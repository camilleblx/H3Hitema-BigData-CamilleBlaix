# %% [raw]
# 1) Importez les librairies qu’il vous faut

# %%
import numpy as np
import pandas as pd
import matplotlib as mp 
import seaborn as sns

# %%
df = pd.read_csv('/Users/camilleblx/Desktop/Development-BigData/yourenv/bin/ibm_hr_attrition.csv')
print('data loaded')
# Out:
# data loaded

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.columns.to_list()
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %% [raw]
# 2) En utilisant catplot(), construisez un graphique qui vous permette de voir la distribution
# des personnes qui ont quitté l’entreprise par rapport à leur JobSatisfaction

# %%
sns.catplot(x='Attrition', y='JobSatisfaction', kind="bar", data=df)

# %% [raw]
# 3) Changez de graphique et utilisez plutôt un boxplot, que pouvez vous conclure ?

# %%
sns.boxplot(x='Attrition', y='JobSatisfaction', data=df)

# %% [raw]
# Les employées ayant une satisfaction au travail faible quitte l'entreprise.
#
# Il n'y a rien d'aberrants.

# %% [raw]
# 4) Peut-on dire grâce aux boxplot si une variable présente des valeurs aberrantes ?

# %% [raw]
# 5) Isolez les observations présentant des valeurs aberrantes pour la variable
# JobSatisfaction en fonction de la variable indiquant si ils ont quitté l’entreprise ou non

# %% [raw]
# 6) Utilisez la méthode .describe de pandas pour obtenir un tableau récapitulatif des
# statistiques descriptives du dataset.

# %%
df.describe(include='all')
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# ...

# %% [raw]
# 7) Comparez les individus présentant des valeurs aberrantes pour la variable
# JobSatisfaction avec les statistiques descriptives du dataset, remarquez vous des
# différences notoires ?

# %% [raw]
# 8) Faites de même avec le TotalWorkingYears. Que pouvez vous conclure ?

# %%
sns.boxplot(x='Attrition', y='TotalWorkingYears', data=df)

# %% [raw]
# Il y a de fortes abérrations. La majorité part avant 10ans. 75% des persones sont entre 10 et 15 ans de total d'années.

# %% [raw]
# 9) Remplacer les valeurs de la colonne Attrition par 1 pour Yes et 0 pour No

# %%
df_2 = df
df_2.Attrition = df_2.Attrition.replace(to_replace=['Yes','No'],value=[1,0])

# %% [raw]
# 10) En utilisant un Histogramme, regardez la répartition du taux de départ par
# EducationField

# %%
sns.catplot(x='EducationField', y='Attrition', hue="Department", data=dfbis, kind="bar")
